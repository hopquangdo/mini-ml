# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def plot_radar_chart(models, metrics, scores, title='So sánh mô hình (Radar chart)', figsize=(7, 7)):
    num_metrics = len(metrics)
    angles = np.linspace(0, 2 * np.pi, num_metrics, endpoint=False).tolist()
    angles += angles[:1]  # Đóng vòng tròn

    fig, ax = plt.subplots(figsize=figsize, subplot_kw=dict(polar=True))

    for i, model_scores in enumerate(scores):
        data = model_scores.tolist()
        data += data[:1]  # Đóng đa giác
        ax.plot(angles, data, label=models[i])
        ax.fill(angles, data, alpha=0.1)

    ax.set_theta_offset(np.pi / 2)
    ax.set_theta_direction(-1)
    ax.set_thetagrids(np.degrees(angles[:-1]), metrics)
    ax.set_ylim(0, 1)
    plt.title(title, size=14)
    plt.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
    plt.tight_layout()
    plt.show()

# %%
models = ['SVM', 'KNN', 'Decision Tree']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1']
scores = np.array([
    [0.85, 0.83, 0.84, 0.83],
    [0.80, 0.79, 0.78, 0.78],
    [0.75, 0.70, 0.73, 0.71]
])

plot_radar_chart(models, metrics, scores, title='So sánh các mô hình học máy trong bài toán phân loại')

# %%
models = ['SVM', 'KNN', 'Cây quyết định']
metrics = ['Accuracy', 'Precision', 'Recall', 'F1']
scores = np.array([
    [0.85, 0.83, 0.84, 0.83],
    [0.80, 0.79, 0.78, 0.78],
    [0.75, 0.70, 0.73, 0.71]
])

plot_radar_chart(models, metrics, scores, title='So sánh các mô hình học máy trong bài toán phân loại')
